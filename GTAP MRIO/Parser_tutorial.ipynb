# %% [markdown]
# # GTAP MRIO Parsing Tutorial
# This notebook serves as a tutorial for parsing the GTAP Multi-Regional Input-Output (MRIO) database using the MARIO library. The database used in this tutorial is licensed and should be accessed and used in compliance with the licensing terms.
#
# *N.B. To parse the raw CSV files provided with the GTAP license, you need to use the `dev_GTAP` branch of the MARIO GitHub repository. This branch contains a parser for GTAP that is functional but not yet optimized. In this tutorial, we use the stable version of MARIO. The GTAP database has already been parsed using the under-development parser from the `dev_GTAP` branch and then re-exported in MARIO txt format for use here.*
#
#
# ### Import necessary libraries
# This block imports the required libraries and suppresses warnings for cleaner output.

# %%
import mario
import warnings  
warnings.filterwarnings("ignore")  # pandas is becoming a bit too noisy with warnings...

gtap_path = '/Users/lorenzorinaldi/Library/CloudStorage/OneDrive-SharedLibraries-eNextGen/ENTICE - Documents/Database/MARIO/flows'

db = mario.parse_from_txt(
    path=gtap_path,
    table='IOT',
    mode='flows',
    name = 'GTAP11Power - MRIO in MARIO format', # optional
    year= 2017 # optional
    )

# %% [markdown]
# ### Display database properties
# This block displays the properties of the parsed database.

# %%
# Display database properties
db
# Out:
# name = GTAP11Power - MRIO in MARIO format
# table = IOT
# scenarios = ['baseline']
# Factor of production = 25116
# Satellite account = 16837
# Consumption category = 4
# Region = 162
# Sector = 76

# %% [markdown]
# ### Get list of sectors
# This block retrieves the list of sectors available in the database.

# %%
# Get list of sectors
db.get_index('Sector')
# Out:
# ['AFS',
#  'ATP',
#  'BPH',
#  'B_T',
#  'CHM',
#  'CMN',
#  'CMT',
#  'CNS',
#  'COA',
#  'CTL',
#  'C_B',
#  'CoalBL',
#  'DWE',
#  'EDU',
#  'EEQ',
#  'ELE',
#  'FMP',
#  'FRS',
#  'FSH',
#  'GAS',
#  'GDT',
#  'GRO',
#  'GasBL',
#  'GasP',
#  'HHT',
#  'HydroBL',
#  'HydroP',
#  'INS',
#  'I_S',
#  'LEA',
#  'LUM',
#  'MIL',
#  'MVH',
#  'NFM',
#  'NMM',
#  'NuclearBL',
#  'OAP',
#  'OBS',
#  'OCR',
#  'OFD',
#  'OFI',
#  'OIL',
#  'OME',
#  'OMF',
#  'OMT',
#  'OSD',
#  'OSG',
#  'OTN',
#  'OTP',
#  'OXT',
#  'OilBL',
#  'OilP',
#  'OtherBL',
#  'PCR',
#  'PDR',
#  'PFB',
#  'PPP',
#  'P_C',
#  'RMK',
#  'ROS',
#  'RPP',
#  'RSA',
#  'SGR',
#  'SolarP',
#  'TEX',
#  'TRD',
#  'TnD',
#  'VOL',
#  'V_F',
#  'WAP',
#  'WHS',
#  'WHT',
#  'WOL',
#  'WTP',
#  'WTR',
#  'WindBL']

# %% [markdown]
# ### Get list of regions
# This block retrieves the list of regions available in the database.

# %%
# Get list of regions
db.get_index('Region')
# Out:
# ['AFG',
#  'AGO',
#  'ALB',
#  'ARE',
#  'ARG',
#  'ARM',
#  'AUS',
#  'AUT',
#  'AZE',
#  'BDI',
#  'BEL',
#  'BEN',
#  'BFA',
#  'BGD',
#  'BGR',
#  'BHR',
#  'BLR',
#  'BOL',
#  'BRA',
#  'BRN',
#  'BWA',
#  'CAF',
#  'CAN',
#  'CHE',
#  'CHL',
#  'CHN',
#  'CIV',
#  'CMR',
#  'COD',
#  'COG',
#  'COL',
#  'COM',
#  'CRI',
#  'CYP',
#  'CZE',
#  'DEU',
#  'DNK',
#  'DOM',
#  'DZA',
#  'ECU',
#  'EGY',
#  'ESP',
#  'EST',
#  'ETH',
#  'FIN',
#  'FRA',
#  'GAB',
#  'GBR',
#  'GEO',
#  'GHA',
#  'GIN',
#  'GNQ',
#  'GRC',
#  'GTM',
#  'HKG',
#  'HND',
#  'HRV',
#  'HTI',
#  'HUN',
#  'IDN',
#  'IND',
#  'IRL',
#  'IRN',
#  'IRQ',
#  'ISR',
#  'ITA',
#  'JAM',
#  'JOR',
#  'JPN',
#  'KAZ',
#  'KEN',
#  'KGZ',
#  'KHM',
#  'KOR',
#  'KWT',
#  'LAO',
#  'LBN',
#  'LKA',
#  'LTU',
#  'LUX',
#  'LVA',
#  'MAR',
#  'MDG',
#  'MEX',
#  'MLI',
#  'MLT',
#  'MNG',
#  'MOZ',
#  'MUS',
#  'MWI',
#  'MYS',
#  'NAM',
#  'NER',
#  'NGA',
#  'NIC',
#  'NLD',
#  'NOR',
#  'NPL',
#  'NZL',
#  'OMN',
#  'PAK',
#  'PAN',
#  'PER',
#  'PHL',
#  'POL',
#  'PRI',
#  'PRT',
#  'PRY',
#  'PSE',
#  'QAT',
#  'ROU',
#  'RUS',
#  'RWA',
#  'SAU',
#  'SDN',
#  'SEN',
#  'SGP',
#  'SLV',
#  'SRB',
#  'STP',
#  'SVK',
#  'SVN',
#  'SWE',
#  'SWZ',
#  'SYR',
#  'TCD',
#  'TGO',
#  'THA',
#  'TJK',
#  'TTO',
#  'TUN',
#  'TUR',
#  'TWN',
#  'TZA',
#  'UGA',
#  'UKR',
#  'URY',
#  'USA',
#  'UZB',
#  'VEN',
#  'VNM',
#  'XCA',
#  'XCB',
#  'XEA',
#  'XEC',
#  'XEE',
#  'XEF',
#  'XER',
#  'XNA',
#  'XNF',
#  'XOC',
#  'XSA',
#  'XSC',
#  'XSE',
#  'XSM',
#  'XSU',
#  'XTW',
#  'XWF',
#  'XWS',
#  'ZAF',
#  'ZMB',
#  'ZWE']

# %% [markdown]
# ### Get list of factors of production
# This block retrieves the list of factors of production available in the database.

# %%
# Get list of factors of production
db.get_index('Factor of production')
# Out:
# ['MTX_AFG_AFS',
#  'MTX_AFG_ATP',
#  'MTX_AFG_BPH',
#  'MTX_AFG_B_T',
#  'MTX_AFG_CHM',
#  'MTX_AFG_CMN',
#  'MTX_AFG_CMT',
#  'MTX_AFG_CNS',
#  'MTX_AFG_COA',
#  'MTX_AFG_CTL',
#  'MTX_AFG_C_B',
#  'MTX_AFG_CoalBL',
#  'MTX_AFG_DWE',
#  'MTX_AFG_EDU',
#  'MTX_AFG_EEQ',
#  'MTX_AFG_ELE',
#  'MTX_AFG_FMP',
#  'MTX_AFG_FRS',
#  'MTX_AFG_FSH',
#  'MTX_AFG_GAS',
#  'MTX_AFG_GDT',
#  'MTX_AFG_GRO',
#  'MTX_AFG_GasBL',
#  'MTX_AFG_GasP',
#  'MTX_AFG_HHT',
#  'MTX_AFG_HydroBL',
#  'MTX_AFG_HydroP',
#  'MTX_AFG_INS',
#  'MTX_AFG_I_S',
#  'MTX_AFG_LEA',
#  'MTX_AFG_LUM',
#  'MTX_AFG_MIL',
#  'MTX_AFG_MVH',
#  'MTX_AFG_NFM',
#  'MTX_AFG_NMM',
#  'MTX_AFG_NuclearBL',
#  'MTX_AFG_OAP',
#  'MTX_AFG_OBS',
#  'MTX_AFG_OCR',
#  'MTX_AFG_OFD',
#  'MTX_AFG_OFI',
#  'MTX_AFG_OIL',
#  'MTX_AFG_OME',
#  'MTX_AFG_OMF',
#  'MTX_AFG_OMT',
#  'MTX_AFG_OSD',
#  'MTX_AFG_OSG',
#  'MTX_AFG_OTN',
#  'MTX_AFG_OTP',
#  'MTX_AFG_OXT',
#  'MTX_AFG_OilBL',
#  'MTX_AFG_OilP',
#  'MTX_AFG_OtherBL',
#  'MTX_AFG_PCR',
#  'MTX_AFG_PDR',
#  'MTX_AFG_PFB',
#  'MTX_AFG_PPP',
#  'MTX_AFG_P_C',
#  'MTX_AFG_RMK',
#  'MTX_AFG_ROS',
#  'MTX_AFG_RPP',
#  'MTX_AFG_RSA',
#  'MTX_AFG_SGR',
#  'MTX_AFG_SolarP',
#  'MTX_AFG_TEX',
#  'MTX_AFG_TRD',
#  'MTX_AFG_TnD',
#  'MTX_AFG_VOL',
#  'MTX_AFG_V_F',
#  'MTX_AFG_WAP',
#  'MTX_AFG_WHS',
#  'MTX_AFG_WHT',
#  'MTX_AFG_WOL',
#  'MTX_AFG_WTP',
#  'MTX_AFG_WTR',
#  'MTX_AFG_WindBL',
#  'MTX_AGO_AFS',
#  'MTX_AGO_ATP',
#  'MTX_AGO_BPH',
#  'MTX_AGO_B_T',
#  'MTX_AGO_CHM',
#  'MTX_AGO_CMN',
#  'MTX_AGO_CMT',
#  'MTX_AGO_CNS',
#  'MTX_AGO_COA',
#  'MTX_AGO_CTL',
#  'MTX_AGO_C_B',
#  'MTX_AGO_CoalBL',
#  'MTX_AGO_DWE',
#  'MTX_AGO_EDU',
#  'MTX_AGO_EEQ',
#  'MTX_AGO_ELE',
#  'MTX_AGO_FMP',
#  'MTX_AGO_FRS',
#  'MTX_AGO_FSH',
#  'MTX_AGO_GAS',
#  'MTX_AGO_GDT',
#  'MTX_AGO_GRO',
#  'MTX_AGO_GasBL',
#  'MTX_AGO_GasP',
#  'MTX_AGO_HHT',
#  'MTX_AGO_HydroBL',
#  'MTX_AGO_HydroP',
#  'MTX_AGO_INS',
#  'MTX_AGO_I_S',
#  'MTX_AGO_LEA',
#  'MTX_AGO_LUM',
#  'MTX_AGO_MIL',
#  'MTX_AGO_MVH',
#  'MTX_AGO_NFM',
#  'MTX_AGO_NMM',
#  'MTX_AGO_NuclearBL',
#  'MTX_AGO_OAP',
#  'MTX_AGO_OBS',
#  'MTX_AGO_OCR',
#  'MTX_AGO_OFD',
#  'MTX_AGO_OFI',
#  'MTX_AGO_OIL',
#  'MTX_AGO_OME',
#  'MTX_AGO_OMF',
#  'MTX_AGO_OMT',
#  'MTX_AGO_OSD',
#  'MTX_AGO_OSG',
#  'MTX_AGO_OTN',
#  'MTX_AGO_OTP',
#  'MTX_AGO_OXT',
#  'MTX_AGO_OilBL',
#  'MTX_AGO_OilP',
#  'MTX_AGO_OtherBL',
#  'MTX_AGO_PCR',
#  'MTX_AGO_PDR',
#  'MTX_AGO_PFB',
#  'MTX_AGO_PPP',
#  'MTX_AGO_P_C',
#  'MTX_AGO_RMK',
#  'MTX_AGO_ROS',
#  'MTX_AGO_RPP',
#  'MTX_AGO_RSA',
#  'MTX_AGO_SGR',
#  'MTX_AGO_SolarP',
#  'MTX_AGO_TEX',
#  'MTX_AGO_TRD',
#  'MTX_AGO_TnD',
#  'MTX_AGO_VOL',
#  'MTX_AGO_V_F',
#  'MTX_AGO_WAP',
#  'MTX_AGO_WHS',
#  'MTX_AGO_WHT',
#  'MTX_AGO_WOL',
#  'MTX_AGO_WTP',
#  'MTX_AGO_WTR',
#  'MTX_AGO_WindBL',
#  'MTX_ALB_AFS',
#  'MTX_ALB_ATP',
#  'MTX_ALB_BPH',
#  'MTX_ALB_B_T',
#  'MTX_ALB_CHM',
#  'MTX_ALB_CMN',
#  'MTX_ALB_CMT',
#  'MTX_ALB_CNS',
#  'MTX_ALB_COA',
#  'MTX_ALB_CTL',
#  'MTX_ALB_C_B',
#  'MTX_ALB_CoalBL',
#  'MTX_ALB_DWE',
#  'MTX_ALB_EDU',
#  'MTX_ALB_EEQ',
#  'MTX_ALB_ELE',
#  'MTX_ALB_FMP',
#  'MTX_ALB_FRS',
#  'MTX_ALB_FSH',
#  'MTX_ALB_GAS',
#  'MTX_ALB_GDT',
#  'MTX_ALB_GRO',
#  'MTX_ALB_GasBL',
#  'MTX_ALB_GasP',
#  'MTX_ALB_HHT',
#  'MTX_ALB_HydroBL',
#  'MTX_ALB_HydroP',
#  'MTX_ALB_INS',
#  'MTX_ALB_I_S',
#  'MTX_ALB_LEA',
#  'MTX_ALB_LUM',
#  'MTX_ALB_MIL',
#  'MTX_ALB_MVH',
#  'MTX_ALB_NFM',
#  'MTX_ALB_NMM',
#  'MTX_ALB_NuclearBL',
#  'MTX_ALB_OAP',
#  'MTX_ALB_OBS',
#  'MTX_ALB_OCR',
#  'MTX_ALB_OFD',
#  'MTX_ALB_OFI',
#  'MTX_ALB_OIL',
#  'MTX_ALB_OME',
#  'MTX_ALB_OMF',
#  'MTX_ALB_OMT',
#  'MTX_ALB_OSD',
#  'MTX_ALB_OSG',
#  'MTX_ALB_OTN',
#  'MTX_ALB_OTP',
#  'MTX_ALB_OXT',
#  'MTX_ALB_OilBL',
#  'MTX_ALB_OilP',
#  'MTX_ALB_OtherBL',
#  'MTX_ALB_PCR',
#  'MTX_ALB_PDR',
#  'MTX_ALB_PFB',
#  'MTX_ALB_PPP',
#  'MTX_ALB_P_C',
#  'MTX_ALB_RMK',
#  'MTX_ALB_ROS',
#  'MTX_ALB_RPP',
#  'MTX_ALB_RSA',
#  'MTX_ALB_SGR',
#  'MTX_ALB_SolarP',
#  'MTX_ALB_TEX',
#  'MTX_ALB_TRD',
#  'MTX_ALB_TnD',
#  'MTX_ALB_VOL',
#  'MTX_ALB_V_F',
#  'MTX_ALB_WAP',
#  'MTX_ALB_WHS',
#  'MTX_ALB_WHT',
#  'MTX_ALB_WOL',
#  'MTX_ALB_WTP',
#  'MTX_ALB_WTR',
#  'MTX_ALB_WindBL',
#  'MTX_ARE_AFS',
#  'MTX_ARE_ATP',
#  'MTX_ARE_BPH',
#  'MTX_ARE_B_T',
#  'MTX_ARE_CHM',
#  'MTX_ARE_CMN',
#  'MTX_ARE_CMT',
#  'MTX_ARE_CNS',
#  'MTX_ARE_COA',
#  'MTX_ARE_CTL',
#  'MTX_ARE_C_B',
#  'MTX_ARE_CoalBL',
#  'MTX_ARE_DWE',
#  'MTX_ARE_EDU',
#  'MTX_ARE_EEQ',
#  'MTX_ARE_ELE',
#  'MTX_ARE_FMP',
#  'MTX_ARE_FRS',
#  'MTX_ARE_FSH',
#  'MTX_ARE_GAS',
#  'MTX_ARE_GDT',
#  'MTX_ARE_GRO',
#  'MTX_ARE_GasBL',
#  'MTX_ARE_GasP',
#  'MTX_ARE_HHT',
#  'MTX_ARE_HydroBL',
#  'MTX_ARE_HydroP',
#  'MTX_ARE_INS',
#  'MTX_ARE_I_S',
#  'MTX_ARE_LEA',
#  'MTX_ARE_LUM',
#  'MTX_ARE_MIL',
#  'MTX_ARE_MVH',
#  'MTX_ARE_NFM',
#  'MTX_ARE_NMM',
#  'MTX_ARE_NuclearBL',
#  'MTX_ARE_OAP',
#  'MTX_ARE_OBS',
#  'MTX_ARE_OCR',
#  'MTX_ARE_OFD',
#  'MTX_ARE_OFI',
#  'MTX_ARE_OIL',
#  'MTX_ARE_OME',
#  'MTX_ARE_OMF',
#  'MTX_ARE_OMT',
#  'MTX_ARE_OSD',
#  'MTX_ARE_OSG',
#  'MTX_ARE_OTN',
#  'MTX_ARE_OTP',
#  'MTX_ARE_OXT',
#  'MTX_ARE_OilBL',
#  'MTX_ARE_OilP',
#  'MTX_ARE_OtherBL',
#  'MTX_ARE_PCR',
#  'MTX_ARE_PDR',
#  'MTX_ARE_PFB',
#  'MTX_ARE_PPP',
#  'MTX_ARE_P_C',
#  'MTX_ARE_RMK',
#  'MTX_ARE_ROS',
#  'MTX_ARE_RPP',
#  'MTX_ARE_RSA',
#  'MTX_ARE_SGR',
#  'MTX_ARE_SolarP',
#  'MTX_ARE_TEX',
#  'MTX_ARE_TRD',
#  'MTX_ARE_TnD',
#  'MTX_ARE_VOL',
#  'MTX_ARE_V_F',
#  'MTX_ARE_WAP',
#  'MTX_ARE_WHS',
#  'MTX_ARE_WHT',
#  'MTX_ARE_WOL',
#  'MTX_ARE_WTP',
#  'MTX_ARE_WTR',
#  'MTX_ARE_WindBL',
#  'MTX_ARG_AFS',
#  'MTX_ARG_ATP',
#  'MTX_ARG_BPH',
#  'MTX_ARG_B_T',
#  'MTX_ARG_CHM',
#  'MTX_ARG_CMN',
#  'MTX_ARG_CMT',
#  'MTX_ARG_CNS',
#  'MTX_ARG_COA',
#  'MTX_ARG_CTL',
#  'MTX_ARG_C_B',
#  'MTX_ARG_CoalBL',
#  'MTX_ARG_DWE',
#  'MTX_ARG_EDU',
#  'MTX_ARG_EEQ',
#  'MTX_ARG_ELE',
#  'MTX_ARG_FMP',
#  'MTX_ARG_FRS',
#  'MTX_ARG_FSH',
#  'MTX_ARG_GAS',
#  'MTX_ARG_GDT',
#  'MTX_ARG_GRO',
#  'MTX_ARG_GasBL',
#  'MTX_ARG_GasP',
#  'MTX_ARG_HHT',
#  'MTX_ARG_HydroBL',
#  'MTX_ARG_HydroP',
#  'MTX_ARG_INS',
#  'MTX_ARG_I_S',
#  'MTX_ARG_LEA',
#  'MTX_ARG_LUM',
#  'MTX_ARG_MIL',
#  'MTX_ARG_MVH',
#  'MTX_ARG_NFM',
#  'MTX_ARG_NMM',
#  'MTX_ARG_NuclearBL',
#  'MTX_ARG_OAP',
#  'MTX_ARG_OBS',
#  'MTX_ARG_OCR',
#  'MTX_ARG_OFD',
#  'MTX_ARG_OFI',
#  'MTX_ARG_OIL',
#  'MTX_ARG_OME',
#  'MTX_ARG_OMF',
#  'MTX_ARG_OMT',
#  'MTX_ARG_OSD',
#  'MTX_ARG_OSG',
#  'MTX_ARG_OTN',
#  'MTX_ARG_OTP',
#  'MTX_ARG_OXT',
#  'MTX_ARG_OilBL',
#  'MTX_ARG_OilP',
#  'MTX_ARG_OtherBL',
#  'MTX_ARG_PCR',
#  'MTX_ARG_PDR',
#  'MTX_ARG_PFB',
#  'MTX_ARG_PPP',
#  'MTX_ARG_P_C',
#  'MTX_ARG_RMK',
#  'MTX_ARG_ROS',
#  'MTX_ARG_RPP',
#  'MTX_ARG_RSA',
#  'MTX_ARG_SGR',
#  'MTX_ARG_SolarP',
#  'MTX_ARG_TEX',
#  'MTX_ARG_TRD',
#  'MTX_ARG_TnD',
#  'MTX_ARG_VOL',
#  'MTX_ARG_V_F',
#  'MTX_ARG_WAP',
#  'MTX_ARG_WHS',
#  'MTX_ARG_WHT',
#  'MTX_ARG_WOL',
#  'MTX_ARG_WTP',
#  'MTX_ARG_WTR',
#  'MTX_ARG_WindBL',
#  'MTX_ARM_AFS',
#  'MTX_ARM_ATP',
#  'MTX_ARM_BPH',
#  'MTX_ARM_B_T',
#  'MTX_ARM_CHM',
#  'MTX_ARM_CMN',
#  'MTX_ARM_CMT',
#  'MTX_ARM_CNS',
#  'MTX_ARM_COA',
#  'MTX_ARM_CTL',
#  'MTX_ARM_C_B',
#  'MTX_ARM_CoalBL',
#  'MTX_ARM_DWE',
#  'MTX_ARM_EDU',
#  'MTX_ARM_EEQ',
#  'MTX_ARM_ELE',
#  'MTX_ARM_FMP',
#  'MTX_ARM_FRS',
#  'MTX_ARM_FSH',
#  'MTX_ARM_GAS',
#  'MTX_ARM_GDT',
#  'MTX_ARM_GRO',
#  'MTX_ARM_GasBL',
#  'MTX_ARM_GasP',
#  'MTX_ARM_HHT',
#  'MTX_ARM_HydroBL',
#  'MTX_ARM_HydroP',
#  'MTX_ARM_INS',
#  'MTX_ARM_I_S',
#  'MTX_ARM_LEA',
#  'MTX_ARM_LUM',
#  'MTX_ARM_MIL',
#  'MTX_ARM_MVH',
#  'MTX_ARM_NFM',
#  'MTX_ARM_NMM',
#  'MTX_ARM_NuclearBL',
#  'MTX_ARM_OAP',
#  'MTX_ARM_OBS',
#  'MTX_ARM_OCR',
#  'MTX_ARM_OFD',
#  'MTX_ARM_OFI',
#  'MTX_ARM_OIL',
#  'MTX_ARM_OME',
#  'MTX_ARM_OMF',
#  'MTX_ARM_OMT',
#  'MTX_ARM_OSD',
#  'MTX_ARM_OSG',
#  'MTX_ARM_OTN',
#  'MTX_ARM_OTP',
#  'MTX_ARM_OXT',
#  'MTX_ARM_OilBL',
#  'MTX_ARM_OilP',
#  'MTX_ARM_OtherBL',
#  'MTX_ARM_PCR',
#  'MTX_ARM_PDR',
#  'MTX_ARM_PFB',
#  'MTX_ARM_PPP',
#  'MTX_ARM_P_C',
#  'MTX_ARM_RMK',
#  'MTX_ARM_ROS',
#  'MTX_ARM_RPP',
#  'MTX_ARM_RSA',
#  'MTX_ARM_SGR',
#  'MTX_ARM_SolarP',
#  'MTX_ARM_TEX',
#  'MTX_ARM_TRD',
#  'MTX_ARM_TnD',
#  'MTX_ARM_VOL',
#  'MTX_ARM_V_F',
#  'MTX_ARM_WAP',
#  'MTX_ARM_WHS',
#  'MTX_ARM_WHT',
#  'MTX_ARM_WOL',
#  'MTX_ARM_WTP',
#  'MTX_ARM_WTR',
#  'MTX_ARM_WindBL',
#  'MTX_AUS_AFS',
#  'MTX_AUS_ATP',
#  'MTX_AUS_BPH',
#  'MTX_AUS_B_T',
#  'MTX_AUS_CHM',
#  'MTX_AUS_CMN',
#  'MTX_AUS_CMT',
#  'MTX_AUS_CNS',
#  'MTX_AUS_COA',
#  'MTX_AUS_CTL',
#  'MTX_AUS_C_B',
#  'MTX_AUS_CoalBL',
#  'MTX_AUS_DWE',
#  'MTX_AUS_EDU',
#  'MTX_AUS_EEQ',
#  'MTX_AUS_ELE',
#  'MTX_AUS_FMP',
#  'MTX_AUS_FRS',
#  'MTX_AUS_FSH',
#  'MTX_AUS_GAS',
#  'MTX_AUS_GDT',
#  'MTX_AUS_GRO',
#  'MTX_AUS_GasBL',
#  'MTX_AUS_GasP',
#  'MTX_AUS_HHT',
#  'MTX_AUS_HydroBL',
#  'MTX_AUS_HydroP',
#  'MTX_AUS_INS',
#  'MTX_AUS_I_S',
#  'MTX_AUS_LEA',
#  'MTX_AUS_LUM',
#  'MTX_AUS_MIL',
#  'MTX_AUS_MVH',
#  'MTX_AUS_NFM',
#  'MTX_AUS_NMM',
#  'MTX_AUS_NuclearBL',
#  'MTX_AUS_OAP',
#  'MTX_AUS_OBS',
#  'MTX_AUS_OCR',
#  'MTX_AUS_OFD',
#  'MTX_AUS_OFI',
#  'MTX_AUS_OIL',
#  'MTX_AUS_OME',
#  'MTX_AUS_OMF',
#  'MTX_AUS_OMT',
#  'MTX_AUS_OSD',
#  'MTX_AUS_OSG',
#  'MTX_AUS_OTN',
#  'MTX_AUS_OTP',
#  'MTX_AUS_OXT',
#  'MTX_AUS_OilBL',
#  'MTX_AUS_OilP',
#  'MTX_AUS_OtherBL',
#  'MTX_AUS_PCR',
#  'MTX_AUS_PDR',
#  'MTX_AUS_PFB',
#  'MTX_AUS_PPP',
#  'MTX_AUS_P_C',
#  'MTX_AUS_RMK',
#  'MTX_AUS_ROS',
#  'MTX_AUS_RPP',
#  'MTX_AUS_RSA',
#  'MTX_AUS_SGR',
#  'MTX_AUS_SolarP',
#  'MTX_AUS_TEX',
#  'MTX_AUS_TRD',
#  'MTX_AUS_TnD',
#  'MTX_AUS_VOL',
#  'MTX_AUS_V_F',
#  'MTX_AUS_WAP',
#  'MTX_AUS_WHS',
#  'MTX_AUS_WHT',
#  'MTX_AUS_WOL',
#  'MTX_AUS_WTP',
#  'MTX_AUS_WTR',
#  'MTX_AUS_WindBL',
#  'MTX_AUT_AFS',
#  'MTX_AUT_ATP',
#  'MTX_AUT_BPH',
#  'MTX_AUT_B_T',
#  'MTX_AUT_CHM',
#  'MTX_AUT_CMN',
#  'MTX_AUT_CMT',
#  'MTX_AUT_CNS',
#  'MTX_AUT_COA',
#  'MTX_AUT_CTL',
#  'MTX_AUT_C_B',
#  'MTX_AUT_CoalBL',
#  'MTX_AUT_DWE',
#  'MTX_AUT_EDU',
#  'MTX_AUT_EEQ',
#  'MTX_AUT_ELE',
#  'MTX_AUT_FMP',
#  'MTX_AUT_FRS',
#  'MTX_AUT_FSH',
#  'MTX_AUT_GAS',
#  'MTX_AUT_GDT',
#  'MTX_AUT_GRO',
#  'MTX_AUT_GasBL',
#  'MTX_AUT_GasP',
#  'MTX_AUT_HHT',
#  'MTX_AUT_HydroBL',
#  'MTX_AUT_HydroP',
#  'MTX_AUT_INS',
#  'MTX_AUT_I_S',
#  'MTX_AUT_LEA',
#  'MTX_AUT_LUM',
#  'MTX_AUT_MIL',
#  'MTX_AUT_MVH',
#  'MTX_AUT_NFM',
#  'MTX_AUT_NMM',
#  'MTX_AUT_NuclearBL',
#  'MTX_AUT_OAP',
#  'MTX_AUT_OBS',
#  'MTX_AUT_OCR',
#  'MTX_AUT_OFD',
#  'MTX_AUT_OFI',
#  'MTX_AUT_OIL',
#  'MTX_AUT_OME',
#  'MTX_AUT_OMF',
#  'MTX_AUT_OMT',
#  'MTX_AUT_OSD',
#  'MTX_AUT_OSG',
#  'MTX_AUT_OTN',
#  'MTX_AUT_OTP',
#  'MTX_AUT_OXT',
#  'MTX_AUT_OilBL',
#  'MTX_AUT_OilP',
#  'MTX_AUT_OtherBL',
#  'MTX_AUT_PCR',
#  'MTX_AUT_PDR',
#  'MTX_AUT_PFB',
#  'MTX_AUT_PPP',
#  'MTX_AUT_P_C',
#  'MTX_AUT_RMK',
#  'MTX_AUT_ROS',
#  'MTX_AUT_RPP',
#  'MTX_AUT_RSA',
#  'MTX_AUT_SGR',
#  'MTX_AUT_SolarP',
#  'MTX_AUT_TEX',
#  'MTX_AUT_TRD',
#  'MTX_AUT_TnD',
#  'MTX_AUT_VOL',
#  'MTX_AUT_V_F',
#  'MTX_AUT_WAP',
#  'MTX_AUT_WHS',
#  'MTX_AUT_WHT',
#  'MTX_AUT_WOL',
#  'MTX_AUT_WTP',
#  'MTX_AUT_WTR',
#  'MTX_AUT_WindBL',
#  'MTX_AZE_AFS',
#  'MTX_AZE_ATP',
#  'MTX_AZE_BPH',
#  'MTX_AZE_B_T',
#  'MTX_AZE_CHM',
#  'MTX_AZE_CMN',
#  'MTX_AZE_CMT',
#  'MTX_AZE_CNS',
#  'MTX_AZE_COA',
#  'MTX_AZE_CTL',
#  'MTX_AZE_C_B',
#  'MTX_AZE_CoalBL',
#  'MTX_AZE_DWE',
#  'MTX_AZE_EDU',
#  'MTX_AZE_EEQ',
#  'MTX_AZE_ELE',
#  'MTX_AZE_FMP',
#  'MTX_AZE_FRS',
#  'MTX_AZE_FSH',
#  'MTX_AZE_GAS',
#  'MTX_AZE_GDT',
#  'MTX_AZE_GRO',
#  'MTX_AZE_GasBL',
#  'MTX_AZE_GasP',
#  'MTX_AZE_HHT',
#  'MTX_AZE_HydroBL',
#  'MTX_AZE_HydroP',
#  'MTX_AZE_INS',
#  'MTX_AZE_I_S',
#  'MTX_AZE_LEA',
#  'MTX_AZE_LUM',
#  'MTX_AZE_MIL',
#  'MTX_AZE_MVH',
#  'MTX_AZE_NFM',
#  'MTX_AZE_NMM',
#  'MTX_AZE_NuclearBL',
#  'MTX_AZE_OAP',
#  'MTX_AZE_OBS',
#  'MTX_AZE_OCR',
#  'MTX_AZE_OFD',
#  'MTX_AZE_OFI',
#  'MTX_AZE_OIL',
#  'MTX_AZE_OME',
#  'MTX_AZE_OMF',
#  'MTX_AZE_OMT',
#  'MTX_AZE_OSD',
#  'MTX_AZE_OSG',
#  'MTX_AZE_OTN',
#  'MTX_AZE_OTP',
#  'MTX_AZE_OXT',
#  'MTX_AZE_OilBL',
#  'MTX_AZE_OilP',
#  'MTX_AZE_OtherBL',
#  'MTX_AZE_PCR',
#  'MTX_AZE_PDR',
#  'MTX_AZE_PFB',
#  'MTX_AZE_PPP',
#  'MTX_AZE_P_C',
#  'MTX_AZE_RMK',
#  'MTX_AZE_ROS',
#  'MTX_AZE_RPP',
#  'MTX_AZE_RSA',
#  'MTX_AZE_SGR',
#  'MTX_AZE_SolarP',
#  'MTX_AZE_TEX',
#  'MTX_AZE_TRD',
#  'MTX_AZE_TnD',
#  'MTX_AZE_VOL',
#  'MTX_AZE_V_F',
#  'MTX_AZE_WAP',
#  'MTX_AZE_WHS',
#  'MTX_AZE_WHT',
#  'MTX_AZE_WOL',
#  'MTX_AZE_WTP',
#  'MTX_AZE_WTR',
#  'MTX_AZE_WindBL',
#  'MTX_BDI_AFS',
#  'MTX_BDI_ATP',
#  'MTX_BDI_BPH',
#  'MTX_BDI_B_T',
#  'MTX_BDI_CHM',
#  'MTX_BDI_CMN',
#  'MTX_BDI_CMT',
#  'MTX_BDI_CNS',
#  'MTX_BDI_COA',
#  'MTX_BDI_CTL',
#  'MTX_BDI_C_B',
#  'MTX_BDI_CoalBL',
#  'MTX_BDI_DWE',
#  'MTX_BDI_EDU',
#  'MTX_BDI_EEQ',
#  'MTX_BDI_ELE',
#  'MTX_BDI_FMP',
#  'MTX_BDI_FRS',
#  'MTX_BDI_FSH',
#  'MTX_BDI_GAS',
#  'MTX_BDI_GDT',
#  'MTX_BDI_GRO',
#  'MTX_BDI_GasBL',
#  'MTX_BDI_GasP',
#  'MTX_BDI_HHT',
#  'MTX_BDI_HydroBL',
#  'MTX_BDI_HydroP',
#  'MTX_BDI_INS',
#  'MTX_BDI_I_S',
#  'MTX_BDI_LEA',
#  'MTX_BDI_LUM',
#  'MTX_BDI_MIL',
#  'MTX_BDI_MVH',
#  'MTX_BDI_NFM',
#  'MTX_BDI_NMM',
#  'MTX_BDI_NuclearBL',
#  'MTX_BDI_OAP',
#  'MTX_BDI_OBS',
#  'MTX_BDI_OCR',
#  'MTX_BDI_OFD',
#  'MTX_BDI_OFI',
#  'MTX_BDI_OIL',
#  'MTX_BDI_OME',
#  'MTX_BDI_OMF',
#  'MTX_BDI_OMT',
#  'MTX_BDI_OSD',
#  'MTX_BDI_OSG',
#  'MTX_BDI_OTN',
#  'MTX_BDI_OTP',
#  'MTX_BDI_OXT',
#  'MTX_BDI_OilBL',
#  'MTX_BDI_OilP',
#  'MTX_BDI_OtherBL',
#  'MTX_BDI_PCR',
#  'MTX_BDI_PDR',
#  'MTX_BDI_PFB',
#  'MTX_BDI_PPP',
#  'MTX_BDI_P_C',
#  'MTX_BDI_RMK',
#  'MTX_BDI_ROS',
#  'MTX_BDI_RPP',
#  'MTX_BDI_RSA',
#  'MTX_BDI_SGR',
#  'MTX_BDI_SolarP',
#  'MTX_BDI_TEX',
#  'MTX_BDI_TRD',
#  'MTX_BDI_TnD',
#  'MTX_BDI_VOL',
#  'MTX_BDI_V_F',
#  'MTX_BDI_WAP',
#  'MTX_BDI_WHS',
#  'MTX_BDI_WHT',
#  'MTX_BDI_WOL',
#  'MTX_BDI_WTP',
#  'MTX_BDI_WTR',
#  'MTX_BDI_WindBL',
#  'MTX_BEL_AFS',
#  'MTX_BEL_ATP',
#  'MTX_BEL_BPH',
#  'MTX_BEL_B_T',
#  'MTX_BEL_CHM',
#  'MTX_BEL_CMN',
#  'MTX_BEL_CMT',
#  'MTX_BEL_CNS',
#  'MTX_BEL_COA',
#  'MTX_BEL_CTL',
#  'MTX_BEL_C_B',
#  'MTX_BEL_CoalBL',
#  'MTX_BEL_DWE',
#  'MTX_BEL_EDU',
#  'MTX_BEL_EEQ',
#  'MTX_BEL_ELE',
#  'MTX_BEL_FMP',
#  'MTX_BEL_FRS',
#  'MTX_BEL_FSH',
#  'MTX_BEL_GAS',
#  'MTX_BEL_GDT',
#  'MTX_BEL_GRO',
#  'MTX_BEL_GasBL',
#  'MTX_BEL_GasP',
#  'MTX_BEL_HHT',
#  'MTX_BEL_HydroBL',
#  'MTX_BEL_HydroP',
#  'MTX_BEL_INS',
#  'MTX_BEL_I_S',
#  'MTX_BEL_LEA',
#  'MTX_BEL_LUM',
#  'MTX_BEL_MIL',
#  'MTX_BEL_MVH',
#  'MTX_BEL_NFM',
#  'MTX_BEL_NMM',
#  'MTX_BEL_NuclearBL',
#  'MTX_BEL_OAP',
#  'MTX_BEL_OBS',
#  'MTX_BEL_OCR',
#  'MTX_BEL_OFD',
#  'MTX_BEL_OFI',
#  'MTX_BEL_OIL',
#  'MTX_BEL_OME',
#  'MTX_BEL_OMF',
#  'MTX_BEL_OMT',
#  'MTX_BEL_OSD',
#  'MTX_BEL_OSG',
#  'MTX_BEL_OTN',
#  'MTX_BEL_OTP',
#  'MTX_BEL_OXT',
#  'MTX_BEL_OilBL',
#  'MTX_BEL_OilP',
#  'MTX_BEL_OtherBL',
#  'MTX_BEL_PCR',
#  'MTX_BEL_PDR',
#  'MTX_BEL_PFB',
#  'MTX_BEL_PPP',
#  'MTX_BEL_P_C',
#  'MTX_BEL_RMK',
#  'MTX_BEL_ROS',
#  'MTX_BEL_RPP',
#  'MTX_BEL_RSA',
#  'MTX_BEL_SGR',
#  'MTX_BEL_SolarP',
#  'MTX_BEL_TEX',
#  'MTX_BEL_TRD',
#  'MTX_BEL_TnD',
#  'MTX_BEL_VOL',
#  'MTX_BEL_V_F',
#  'MTX_BEL_WAP',
#  'MTX_BEL_WHS',
#  'MTX_BEL_WHT',
#  'MTX_BEL_WOL',
#  'MTX_BEL_WTP',
#  'MTX_BEL_WTR',
#  'MTX_BEL_WindBL',
#  'MTX_BEN_AFS',
#  'MTX_BEN_ATP',
#  'MTX_BEN_BPH',
#  'MTX_BEN_B_T',
#  'MTX_BEN_CHM',
#  'MTX_BEN_CMN',
#  'MTX_BEN_CMT',
#  'MTX_BEN_CNS',
#  'MTX_BEN_COA',
#  'MTX_BEN_CTL',
#  'MTX_BEN_C_B',
#  'MTX_BEN_CoalBL',
#  'MTX_BEN_DWE',
#  'MTX_BEN_EDU',
#  'MTX_BEN_EEQ',
#  'MTX_BEN_ELE',
#  'MTX_BEN_FMP',
#  'MTX_BEN_FRS',
#  'MTX_BEN_FSH',
#  'MTX_BEN_GAS',
#  'MTX_BEN_GDT',
#  'MTX_BEN_GRO',
#  'MTX_BEN_GasBL',
#  'MTX_BEN_GasP',
#  'MTX_BEN_HHT',
#  'MTX_BEN_HydroBL',
#  'MTX_BEN_HydroP',
#  'MTX_BEN_INS',
#  'MTX_BEN_I_S',
#  'MTX_BEN_LEA',
#  'MTX_BEN_LUM',
#  'MTX_BEN_MIL',
#  'MTX_BEN_MVH',
#  'MTX_BEN_NFM',
#  'MTX_BEN_NMM',
#  'MTX_BEN_NuclearBL',
#  'MTX_BEN_OAP',
#  'MTX_BEN_OBS',
#  'MTX_BEN_OCR',
#  'MTX_BEN_OFD',
#  'MTX_BEN_OFI',
#  'MTX_BEN_OIL',
#  'MTX_BEN_OME',
#  'MTX_BEN_OMF',
#  'MTX_BEN_OMT',
#  'MTX_BEN_OSD',
#  'MTX_BEN_OSG',
#  'MTX_BEN_OTN',
#  'MTX_BEN_OTP',
#  'MTX_BEN_OXT',
#  'MTX_BEN_OilBL',
#  'MTX_BEN_OilP',
#  'MTX_BEN_OtherBL',
#  'MTX_BEN_PCR',
#  'MTX_BEN_PDR',
#  'MTX_BEN_PFB',
#  'MTX_BEN_PPP',
#  'MTX_BEN_P_C',
#  'MTX_BEN_RMK',
#  'MTX_BEN_ROS',
#  'MTX_BEN_RPP',
#  'MTX_BEN_RSA',
#  'MTX_BEN_SGR',
#  'MTX_BEN_SolarP',
#  'MTX_BEN_TEX',
#  'MTX_BEN_TRD',
#  'MTX_BEN_TnD',
#  'MTX_BEN_VOL',
#  'MTX_BEN_V_F',
#  'MTX_BEN_WAP',
#  'MTX_BEN_WHS',
#  'MTX_BEN_WHT',
#  'MTX_BEN_WOL',
#  'MTX_BEN_WTP',
#  'MTX_BEN_WTR',
#  'MTX_BEN_WindBL',
#  'MTX_BFA_AFS',
#  'MTX_BFA_ATP',
#  'MTX_BFA_BPH',
#  'MTX_BFA_B_T',
#  'MTX_BFA_CHM',
#  'MTX_BFA_CMN',
#  'MTX_BFA_CMT',
#  'MTX_BFA_CNS',
#  'MTX_BFA_COA',
#  'MTX_BFA_CTL',
#  'MTX_BFA_C_B',
#  'MTX_BFA_CoalBL',
#  'MTX_BFA_DWE',
#  'MTX_BFA_EDU',
#  'MTX_BFA_EEQ',
#  'MTX_BFA_ELE',
#  'MTX_BFA_FMP',
#  'MTX_BFA_FRS',
#  'MTX_BFA_FSH',
#  'MTX_BFA_GAS',
#  'MTX_BFA_GDT',
#  'MTX_BFA_GRO',
#  'MTX_BFA_GasBL',
#  'MTX_BFA_GasP',
#  'MTX_BFA_HHT',
#  'MTX_BFA_HydroBL',
#  'MTX_BFA_HydroP',
#  'MTX_BFA_INS',
#  'MTX_BFA_I_S',
#  'MTX_BFA_LEA',
#  'MTX_BFA_LUM',
#  'MTX_BFA_MIL',
#  'MTX_BFA_MVH',
#  'MTX_BFA_NFM',
#  'MTX_BFA_NMM',
#  'MTX_BFA_NuclearBL',
#  'MTX_BFA_OAP',
#  'MTX_BFA_OBS',
#  'MTX_BFA_OCR',
#  'MTX_BFA_OFD',
#  'MTX_BFA_OFI',
#  'MTX_BFA_OIL',
#  'MTX_BFA_OME',
#  'MTX_BFA_OMF',
#  'MTX_BFA_OMT',
#  'MTX_BFA_OSD',
#  'MTX_BFA_OSG',
#  'MTX_BFA_OTN',
#  'MTX_BFA_OTP',
#  'MTX_BFA_OXT',
#  'MTX_BFA_OilBL',
#  'MTX_BFA_OilP',
#  'MTX_BFA_OtherBL',
#  'MTX_BFA_PCR',
#  'MTX_BFA_PDR',
#  'MTX_BFA_PFB',
#  'MTX_BFA_PPP',
#  'MTX_BFA_P_C',
#  'MTX_BFA_RMK',
#  'MTX_BFA_ROS',
#  'MTX_BFA_RPP',
#  'MTX_BFA_RSA',
#  'MTX_BFA_SGR',
#  'MTX_BFA_SolarP',
#  'MTX_BFA_TEX',
#  'MTX_BFA_TRD',
#  'MTX_BFA_TnD',
#  'MTX_BFA_VOL',
#  'MTX_BFA_V_F',
#  'MTX_BFA_WAP',
#  'MTX_BFA_WHS',
#  'MTX_BFA_WHT',
#  'MTX_BFA_WOL',
#  'MTX_BFA_WTP',
#  'MTX_BFA_WTR',
#  'MTX_BFA_WindBL',
#  'MTX_BGD_AFS',
#  'MTX_BGD_ATP',
#  'MTX_BGD_BPH',
#  'MTX_BGD_B_T',
#  'MTX_BGD_CHM',
#  'MTX_BGD_CMN',
#  'MTX_BGD_CMT',
#  'MTX_BGD_CNS',
#  'MTX_BGD_COA',
#  'MTX_BGD_CTL',
#  'MTX_BGD_C_B',
#  'MTX_BGD_CoalBL',
#  ...]

# %% [markdown]
# ### Check if the database is balanced
# This block checks whether the database is balanced based on coefficients or flows.

# %%
# Check if the database is balanced
db.is_balanced('coefficients')  # can be 'coefficients' or 'flows
# Out:
# +------------------------------+----------+
# |                              |      v+z |
# |------------------------------+----------|
# | ('AFG', 'Sector', 'OtherBL') | 0.436876 |
# | ('GIN', 'Sector', 'OtherBL') | 0.65208  |
# | ('TCD', 'Sector', 'SolarP')  | 0.916178 |
# | ('TCD', 'Sector', 'WOL')     | 1.27388  |
# +------------------------------+----------+
# False

# %% [markdown]
# ### Check units of satellite accounts
# This block retrieves the units of the satellite accounts in the database.

# %%
# Check units of satellite accounts
db.units['Satellite account']
# Out:
#                   unit
# EMI_BC_dom_COA   M ton
# EMI_BC_dom_FRS   M ton
# EMI_BC_dom_GAS   M ton
# EMI_BC_dom_GDT   M ton
# EMI_BC_dom_LUM   M ton
# ...                ...
# ENE_ZWE_OilP     M toe
# ENE_ZWE_OtherBL  M toe
# ENE_ZWE_P_C      M toe
# ENE_ZWE_SolarP   M toe
# ENE_ZWE_WindBL   M toe
#
# [16837 rows x 1 columns]

# %% [markdown]
# ### Calculate GDP by region
# This block calculates the GDP for each region in the database.

# %%
# Calculate GDP by region
db.GDP()
# Out:
#                   GDP
# Region
# AFG      18248.351594
# AGO      68699.180391
# ALB      11909.942461
# ARE     385351.710635
# ARG     615772.551258
# ...               ...
# XWF      16176.320060
# XWS      19864.369536
# ZAF     366195.030690
# ZMB      25445.535290
# ZWE      17203.003417
#
# [162 rows x 1 columns]

# %% [markdown]
# ### Analyze CO2 emissions
# This block searches for CO2 emissions in the satellite accounts, aggregates them by region, and copies the results to the clipboard.

# %%
CO2 = db.search('Satellite account', 'EMI_CO2')
sN = slice(None)
CO2 = db.E.loc[CO2,:].groupby(level = ['Region'],axis=1).sum()
CO2
# Out:
# Region                    AFG           AGO           ALB           ARE  \
# Item
# EMI_CO2_dom_CHM  3.050142e-01  0.000000e+00  2.420000e-02  0.000000e+00
# EMI_CO2_dom_COA  3.089111e+00  7.268345e-04  2.717599e-01  3.235930e-02
# EMI_CO2_dom_GAS  1.431265e-01  9.174240e-01  7.421092e-02  6.047377e+01
# EMI_CO2_dom_GDT  1.713738e-01  7.451729e-01  1.270370e-02  1.796530e+01
# EMI_CO2_dom_NMM  0.000000e+00  0.000000e+00  1.738288e-02  0.000000e+00
# ...                       ...           ...           ...           ...
# EMI_CO2_ZWE_COA  1.425000e-07  6.500000e-08  7.687500e-06  2.204372e-04
# EMI_CO2_ZWE_GAS  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# EMI_CO2_ZWE_GDT  0.000000e+00  3.000000e-10  1.500000e-09  3.644000e-07
# EMI_CO2_ZWE_OIL  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# EMI_CO2_ZWE_P_C  3.300000e-09  3.516000e-07  2.410000e-08  1.820000e-08
#
# Region                    ARG           ARM           AUS           AUT  \
# Item
# EMI_CO2_dom_CHM  9.469427e-01  2.828571e-03  1.640728e+00  2.200000e-02
# EMI_CO2_dom_COA  1.741555e-01  1.297307e-04  1.706708e+02  9.602705e-03
# EMI_CO2_dom_GAS  1.972629e+01  1.097577e-04  4.681477e+01  2.945415e-02
# EMI_CO2_dom_GDT  3.424919e+01  7.998726e-03  1.387522e+01  3.176983e-01
# EMI_CO2_dom_NMM  5.672298e+00  0.000000e+00  1.461759e+00  8.602789e-02
# ...                       ...           ...           ...           ...
# EMI_CO2_ZWE_COA  3.947360e-05  7.000000e-09  9.389200e-06  4.048990e-05
# EMI_CO2_ZWE_GAS  0.000000e+00  0.000000e+00  3.000000e-10  0.000000e+00
# EMI_CO2_ZWE_GDT  3.207000e-07  1.700000e-09  1.175890e-05  1.107000e-07
# EMI_CO2_ZWE_OIL  1.000000e-10  0.000000e+00  0.000000e+00  0.000000e+00
# EMI_CO2_ZWE_P_C  2.872000e-07  3.200000e-09  1.000500e-06  4.460000e-07
#
# Region                    AZE           BDI  ...           XSC           XSE  \
# Item                                         ...
# EMI_CO2_dom_CHM  9.428570e-03  0.000000e+00  ...  0.000000e+00  3.398999e-01
# EMI_CO2_dom_COA  1.146882e-02  3.667179e-03  ...  9.387681e-03  1.137573e+00
# EMI_CO2_dom_GAS  6.775905e+00  4.438100e-06  ...  1.043420e-05  3.094833e+00
# EMI_CO2_dom_GDT  6.664035e+00  3.114400e-05  ...  5.369485e-04  5.751880e+00
# EMI_CO2_dom_NMM  1.738486e-03  0.000000e+00  ...  0.000000e+00  0.000000e+00
# ...                       ...           ...  ...           ...           ...
# EMI_CO2_ZWE_COA  7.487500e-06  5.744860e-05  ...  5.685054e-04  4.228500e-05
# EMI_CO2_ZWE_GAS  0.000000e+00  0.000000e+00  ...  0.000000e+00  0.000000e+00
# EMI_CO2_ZWE_GDT  2.500000e-09  2.000000e-10  ...  5.000000e-10  6.000000e-10
# EMI_CO2_ZWE_OIL  0.000000e+00  0.000000e+00  ...  1.000000e-08  0.000000e+00
# EMI_CO2_ZWE_P_C  1.380000e-08  1.100000e-09  ...  1.700000e-09  9.900000e-08
#
# Region                    XSM           XSU           XTW           XWF  \
# Item
# EMI_CO2_dom_CHM  0.000000e+00  3.882999e-01  0.000000e+00  0.000000e+00
# EMI_CO2_dom_COA  4.791715e-03  1.131455e-02  3.063460e-05  8.470003e-04
# EMI_CO2_dom_GAS  9.285750e-03  5.497711e+00  1.922390e-05  1.683807e-03
# EMI_CO2_dom_GDT  3.812941e-03  4.537117e+01  3.094450e-05  8.254728e-04
# EMI_CO2_dom_NMM  0.000000e+00  1.432968e-01  0.000000e+00  0.000000e+00
# ...                       ...           ...           ...           ...
# EMI_CO2_ZWE_COA  9.300000e-09  5.530000e-08  5.434000e-07  9.672500e-06
# EMI_CO2_ZWE_GAS  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# EMI_CO2_ZWE_GDT  0.000000e+00  7.800000e-09  0.000000e+00  3.230000e-08
# EMI_CO2_ZWE_OIL  0.000000e+00  0.000000e+00  0.000000e+00  9.000000e-10
# EMI_CO2_ZWE_P_C  1.250000e-08  3.770000e-08  0.000000e+00  2.082000e-07
#
# Region                    XWS         ZAF           ZMB           ZWE
# Item
# EMI_CO2_dom_CHM  0.000000e+00    0.340057  6.662857e-02  0.000000e+00
# EMI_CO2_dom_COA  1.212993e-03  325.032169  1.855662e+00  5.616231e+00
# EMI_CO2_dom_GAS  1.155338e-01    0.025480  5.197350e-05  2.122930e-03
# EMI_CO2_dom_GDT  5.184074e-01    2.070707  1.234405e-04  4.587992e-02
# EMI_CO2_dom_NMM  0.000000e+00    0.157424  0.000000e+00  0.000000e+00
# ...                       ...         ...           ...           ...
# EMI_CO2_ZWE_COA  2.192100e-06    0.001346  4.024190e-04  1.900000e-08
# EMI_CO2_ZWE_GAS  0.000000e+00    0.000000  0.000000e+00  6.700000e-09
# EMI_CO2_ZWE_GDT  4.660000e-08    0.000001  1.000000e-10  5.200000e-09
# EMI_CO2_ZWE_OIL  0.000000e+00    0.000000  0.000000e+00  3.000000e-09
# EMI_CO2_ZWE_P_C  4.520000e-08    0.000301  8.524442e-03  3.400000e-09
#
# [818 rows x 162 columns]

# %% [markdown]
# ### Aggregate database using an Excel file
# This block demonstrates how to aggregate the database using an external Excel file.

# %%
# Get the template to fill
db.get_aggregation_excel(path='Aggregation/Aggregate_GTAP.xlsx')

# %%
# Parse filled template and aggregate the database
db.aggregate(io='Aggregation/Aggregate_GTAP_filled.xlsx')

# %% [markdown]
# ### Check properties of the aggregated database
# This block displays the properties of the aggregated database.

# %%
# Check properties of the aggregated database
db
# Out:
# name = GTAP11Power - MRIO in MARIO format
# table = IOT
# scenarios = ['baseline']
# Factor of production = 3
# Satellite account = 4
# Consumption category = 1
# Region = 2
# Sector = 4

# %% [markdown]
# ### Export database to Excel
# This block exports the database to an Excel file, including flows and coefficients.

# %%
# Export to excel
db.to_excel(
    path='/Users/lorenzorinaldi/Library/CloudStorage/OneDrive-SharedLibraries-eNextGen/ENTICE - Documents/Code/Tutorial/Export/GTAP_aggregated.xlsx',
    flows=True,
    coefficients=True,
    )
